# %%
import pandas as pd

# Lembrar de configurar enconding quando quebrar usando o pandas
vendas_df = pd.read_csv('./planilhas/Contoso - Vendas  - 2017.csv', sep=';')
produtos_df = pd.read_csv('./planilhas/Contoso - Cadastro Produtos.csv', sep=';')
lojas_df = pd.read_csv('./planilhas/Contoso - Lojas.csv', sep=';') 
clientes_df = pd.read_csv('./planilhas/Contoso - Clientes.csv', sep=';')

# clientes_df = clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1) -> axis=1 coluna por padrão é linha

clientes_df = clientes_df[['ID Cliente', 'E-mail']]
produtos_df = produtos_df[['ID Produto', 'Nome da Marca']]
lojas_df = lojas_df[['ID Loja', 'Nome da Loja']]
# vendas_df[0] -> Não funciona
# vendas_df[['Numero da Venda', 'Data da Venda', 'Data do Envio']] -> Pegar várias colunas
# vendas_df['Data da Venda'] -> Apenas uma coluna
# vendas_df['Data da Venda'][0] -> Pega dado específico

display(vendas_df)
display(produtos_df)
display(lojas_df)
display(clientes_df)
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                     2    01/01/2017    06/01/2017         5      308
# 2                     3    01/01/2017    01/01/2017         0      294
# 3                     4    01/01/2017    01/01/2017         0      251
# 4                     5    01/01/2017    07/01/2017         6       94
# ...                 ...           ...           ...       ...      ...
# 980637           980638    31/12/2017    31/12/2017         0      194
# 980638           980639    31/12/2017    06/01/2018         6       32
# 980639           980640    31/12/2017    03/01/2018         3      210
# 980640           980641    31/12/2017    31/12/2017         0       53
# 980641           980642    31/12/2017    31/12/2017         0      309
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %%
vendas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980642 entries, 0 to 980641
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Numero da Venda       980642 non-null  int64
#  1   Data da Venda         980642 non-null  object
#  2   Data do Envio         980642 non-null  object
#  3   ID Canal              980642 non-null  int64
#  4   ID Loja               980642 non-null  int64
#  5   ID Produto            980642 non-null  int64
#  6   ID Promocao           980642 non-null  int64
#  7   ID Cliente            980642 non-null  int64
#  8   Quantidade Vendida    980642 non-null  int64
#  9   Quantidade Devolvida  980642 non-null  int64
# dtypes: int64(8), object(2)
# memory usage: 74.8+ MB

# %%
lojas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID Loja       306 non-null    int64
#  1   Nome da Loja  306 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.9+ KB

# %%
vendas_df
# Out:
#         Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                     1    01/01/2017    02/01/2017         1       86
# 1                372597    21/05/2017    22/05/2017         1       86
# 2                   753    01/01/2017    07/01/2017         6      242
# 3                  1706    01/01/2017    07/01/2017         6      308
# 4                  4179    02/01/2017    02/01/2017         0      308
# ...                 ...           ...           ...       ...      ...
# 980637           972504    28/12/2017    28/12/2017         0      215
# 980638           974753    29/12/2017    29/12/2017         0      154
# 980639           979083    31/12/2017    02/01/2018         2      211
# 980640           970737    28/12/2017    31/12/2017         3      283
# 980641           973398    29/12/2017    31/12/2017         2      115
#
#         ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# ...

# %%
produtos_quantidade = vendas_df[['ID Produto', 'Quantidade Vendida', 'Quantidade Devolvida']]
